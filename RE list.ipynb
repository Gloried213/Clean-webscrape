# %%
import numpy as np
import pandas as pd
import requests
import urllib.request
import json
import string

# %%
path = r'C:\Users\GLai\OneDrive - California Department of Toxic Substances Control\Documents\SCP marketecon research\PFAS Treatment priority product regulation\List of Products and REs_compliance.xlsx'

# %%
re_websites = pd.read_excel(path, sheet_name= 0)
re_websites
# Out:
#    Assigned to Complete?                           Company  \
# 0           TB       NaN                                3M
# 1           TB         x                   Adam's Polishes
# 2           TB       NaN  Adidas (Undercover Brothers Ltd)
# 3           TB       NaN                           Angelus
# 4           TB       NaN                 Apple Brand Guard
# ..         ...       ...                               ...
# 92          DR       NaN                             Waxie
# 93          DR       NaN                            Weiman
# 94          DR       NaN                              Woly
# 95          DR       NaN                             Woosh
# 96          DR       NaN                               Zep
#
#                                Product  \
# 0   Scotchguard Rug & Carpet Protector
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...

# %%
#filter out my portion
gl_portion = re_websites.loc[re_websites['Assigned to'] == 'GL']
gl_portion
# Out:
#    Assigned to Complete?                           Company           Product  \
# 47          GL       NaN                           Griffin               NaN
# 48          GL       NaN                  Groom Industries               NaN
# 49          GL       NaN                    Griot's Garage               NaN
# 50          GL       NaN                         Guardsman               NaN
# 51          GL       NaN            Healthier Home Product               NaN
# 52          GL       NaN  Hendlex/Baltic Nano Technologies               NaN
# 54          GL       NaN                          Hillyard               NaN
# 55          GL       NaN                       Hoover, Inc               NaN
# 56          GL       NaN                       Hydro-force               NaN
# 57          GL       NaN                               ICT  Thetapel AM-5010
# 58          GL       NaN          Implus Brands (Sof Sole)               NaN
# ...

# %%
gl_portion
# Out:
#    Assigned to Complete?                           Company           Product  \
# 47          GL       NaN                           Griffin               NaN
# 48          GL       NaN                  Groom Industries               NaN
# 49          GL       NaN                    Griot's Garage               NaN
# 50          GL       NaN                         Guardsman               NaN
# 51          GL       NaN            Healthier Home Product               NaN
# 52          GL       NaN  Hendlex/Baltic Nano Technologies               NaN
# 54          GL       NaN                          Hillyard               NaN
# 55          GL       NaN                       Hoover, Inc               NaN
# 56          GL       NaN                       Hydro-force               NaN
# 57          GL       NaN                               ICT  Thetapel AM-5010
# 58          GL       NaN          Implus Brands (Sof Sole)               NaN
# ...

# %%
# test if link still works
link_list = gl_portion['links'].values.tolist()
requests_code = []
for link in link_list:
    try:
        requests_code.append(requests.get(f'{link}').status_code)
    except:
        requests_code.append(404)

# %%
gl_portion['requests_code'] = requests_code
# Out:
# C:\Users\GLai\AppData\Local\Temp\ipykernel_8136\1028527382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gl_portion['requests_code'] = requests_code

# %%
gl_portion.to_excel('gl_portion.xlsx')
